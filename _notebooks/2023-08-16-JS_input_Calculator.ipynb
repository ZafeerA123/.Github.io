# %%
---
layout: post
title: Grade Calculator
description: A Tech Talk on Linux and the Bash shell.
toc: false
comments: true
categories: [5.A, C4.1]
courses: { compsci: {week: 4} }
type: hacks
---

# %%
# %%html
# <style>
#   .grade-calculator {
#     border-collapse: collapse;
#     width: 300px;
#     margin: 0 auto;
#   }
#
#   .grade-calculator th, .grade-calculator td {
#     border: 1px solid black;
#     text-align: center;
#     padding: 10px;
#   }
#
#   .calculator-output {
#     grid-column: span 4;
#     grid-row: span 1;
#     padding: 0.25em;
#     font-size: 20px;
#     border: 5px solid black;
#     display: flex;
#     align-items: center;
#   }
#
#   .calculator-grid {
#     display: grid;
#     grid-template-columns: repeat(4, 1fr);
#     gap: 10px;
#   }
#
#   .calculator-grid > div {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     font-size: 24px;
#     height: 60px;
#     border: 2px solid black;
#     cursor: pointer;
#   }
#
#   .calculator-grid .calculator-output {
#     grid-column: span 4;
#   }
#
#   .calculator-grid .calculator-clear {
#     grid-column: span 2;
#     background-color: #f06;
#   }
#
#   .calculator-grid .calculator-equals {
#     background-color: #0f6;
#   }
# </style>
#
# <div id="animation">
#   <table class="grade-calculator">
#     <tr>
#       <th>Course</th>
#       <th>Grade</th>
#     </tr>
#     <tr>
#       <td>Course 1</td>
#       <td contenteditable="true" class="calculator-output" id="output1">0</td>
#     </tr>
#     <tr>
#       <td>Course 2</td>
#       <td contenteditable="true" class="calculator-output" id="output2">0</td>
#     </tr>
#     <tr>
#       <td>Course 3</td>
#       <td contenteditable="true" class="calculator-output" id="output3">0</td>
#     </tr>
#   </table>
#   <div class="calculator-container">
#     <div class="calculator-grid">
#       <!-- Row 1 -->
#       <div class="calculator-number">1</div>
#       <div class="calculator-number">2</div>
#       <div class="calculator-number">3</div>
#       <div class="calculator-operation">+</div>
#       <!-- Row 2 -->
#       <div class="calculator-number">4</div>
#       <div class="calculator-number">5</div>
#       <div class="calculator-number">6</div>
#       <div class="calculator-operation">-</div>
#       <!-- Row 3 -->
#       <div class="calculator-number">7</div>
#       <div class="calculator-number">8</div>
#       <div class="calculator-number">9</div>
#       <div class="calculator-operation">*</div>
#       <!-- Row 4 -->
#       <div class="calculator-clear">A/C</div>
#       <div class="calculator-number">0</div>
#       <div class="calculator-number">.</div>
#       <div class="calculator-operation">/</div> <!-- Division symbol -->
#       <!-- Row 5 -->
#       <div class="calculator-equals">=</div>
#     </div>
#   </div>
# </div>
# Out:
# <style>
#   .grade-calculator {
#     border-collapse: collapse;
#     width: 300px;
#     margin: 0 auto;
#   }
#
#   .grade-calculator th, .grade-calculator td {
#     border: 1px solid black;
#     text-align: center;
#     padding: 10px;
#   }
#
#   .calculator-output {
#     grid-column: span 4;
#     grid-row: span 1;
#     padding: 0.25em;
#     font-size: 20px;
#     border: 5px solid black;
#     display: flex;
#     align-items: center;
#   }
#
#   .calculator-grid {
#     display: grid;
#     grid-template-columns: repeat(4, 1fr);
#     gap: 10px;
#   }
#
#   .calculator-grid > div {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     font-size: 24px;
#     height: 60px;
#     border: 2px solid black;
#     cursor: pointer;
#   }
#
#   .calculator-grid .calculator-output {
#     grid-column: span 4;
#   }
#
#   .calculator-grid .calculator-clear {
#     grid-column: span 2;
#     background-color: #f06;
#   }
#
# ...
